# %%
pip install nltk
# Out:
# Requirement already satisfied: nltk in /usr/local/lib/python3.12/dist-packages (3.9.1)
# Requirement already satisfied: click in /usr/local/lib/python3.12/dist-packages (from nltk) (8.3.1)
# Requirement already satisfied: joblib in /usr/local/lib/python3.12/dist-packages (from nltk) (1.5.3)
# Requirement already satisfied: regex>=2021.8.3 in /usr/local/lib/python3.12/dist-packages (from nltk) (2025.11.3)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.12/dist-packages (from nltk) (4.67.2)

# %%
from nltk.tokenize import word_tokenize
from nltk.corpus import stopwords
from nltk.stem import PorterStemmer, WordNetLemmatizer
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package wordnet to /root/nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# [nltk_data] Downloading package omw-1.4 to /root/nltk_data...
# [nltk_data]   Package omw-1.4 is already up-to-date!
# True

# %%
import nltk

nltk.download('punkt')
nltk.download('punkt_tab')
nltk.download('stopwords')
nltk.download('wordnet')
nltk.download('omw-1.4')
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package punkt_tab to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt_tab.zip.
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package wordnet to /root/nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# [nltk_data] Downloading package omw-1.4 to /root/nltk_data...
# [nltk_data]   Package omw-1.4 is already up-to-date!
# True

# %%
text = '''Get your FREE copy of Volume 2 of our PassItOn Stories eBook filled with 25 new inspirational stories from around the world.

Stories give our lives purpose and create a legacy of who we are and what we’ve done. Each one in this collection is true. They tell of overcoming, meeting unexpected challenges, innovation, the joys of life, lessons learned, and hope restored. As often happens, a story well told reminds us of our own important stories. We trust you will find a part of yourself described among these pages.

We hope you enjoy reading these stories and if you come upon something'''

# %%
text = text.lower()

# %%
print(text)
# Out:
# get your free copy of volume 2 of our passiton stories ebook filled with 25 new inspirational stories from around the world.
#
# stories give our lives purpose and create a legacy of who we are and what we’ve done. each one in this collection is true. they tell of overcoming, meeting unexpected challenges, innovation, the joys of life, lessons learned, and hope restored. as often happens, a story well told reminds us of our own important stories. we trust you will find a part of yourself described among these pages.
#
# we hope you enjoy reading these stories and if you come upon something

# %%
tokens = text.lower().split()
print(tokens)
# Out:
# ['get', 'your', 'free', 'copy', 'of', 'volume', '2', 'of', 'our', 'passiton', 'stories', 'ebook', 'filled', 'with', '25', 'new', 'inspirational', 'stories', 'from', 'around', 'the', 'world.', 'stories', 'give', 'our', 'lives', 'purpose', 'and', 'create', 'a', 'legacy', 'of', 'who', 'we', 'are', 'and', 'what', 'we’ve', 'done.', 'each', 'one', 'in', 'this', 'collection', 'is', 'true.', 'they', 'tell', 'of', 'overcoming,', 'meeting', 'unexpected', 'challenges,', 'innovation,', 'the', 'joys', 'of', 'life,', 'lessons', 'learned,', 'and', 'hope', 'restored.', 'as', 'often', 'happens,', 'a', 'story', 'well', 'told', 'reminds', 'us', 'of', 'our', 'own', 'important', 'stories.', 'we', 'trust', 'you', 'will', 'find', 'a', 'part', 'of', 'yourself', 'described', 'among', 'these', 'pages.', 'we', 'hope', 'you', 'enjoy', 'reading', 'these', 'stories', 'and', 'if', 'you', 'come', 'upon', 'something']

# %%
stop_words = set(stopwords.words('english'))
filtered_tokens = [word for word in tokens if word not in stop_words]
print(stop_words)
print(filtered_tokens)
# Out:
# {'her', 'than', "we've", 'hers', 'these', "mustn't", 's', 'be', 'against', 'o', 't', 'why', 'should', 'more', 'where', 'not', 'hasn', 'other', 'whom', 'is', "that'll", 'further', 'above', 'on', 'once', 'who', 'won', 'had', 'him', "shouldn't", "it's", 'each', 'myself', 'she', 'what', 'or', 'all', 'i', "you're", 'himself', "she'd", 'shan', 'needn', "you'll", "they've", 'did', 'itself', 'ours', 'same', "needn't", 'through', "won't", 'ourselves', 'such', 'll', 'ma', "shan't", 'mightn', 'when', 'down', 'off', "weren't", "didn't", 'isn', 'too', 'was', 'my', 'into', 'its', 'herself', "we'll", 'does', 'some', 'wasn', 'while', 'which', "i'll", 'between', 've', 'do', "mightn't", 'we', "they'll", 'you', 'yourselves', "they'd", "we'd", 'nor', 'in', 'for', 'the', 'of', 'yourself', 'can', "she's", 'yours', "i'd", "haven't", 'they', "it'd", 'then', 'doing', 'until', "he'd", 'under', "aren't", 'an', 're', 'it', "wasn't", 'your', "should've", 'any', 'weren', 'to', "don't", "isn't", 'a', 'but', 'have', 'most', "wouldn't", 'at', 'couldn', 'aren', 'now', 'y', 'as', 'theirs', 'shouldn', 'by', "hasn't", 'how', 'very', 'me', "i've", 'haven', 'because', 'm', 'only', 'with', 'been', 'so', 'few', 'here', 'and', 'are', 'he', 'them', 'his', "he's", 'if', 'up', 'having', "he'll", 'those', 'has', "you've", 'again', "couldn't", "it'll", 'below', 'were', 'will', 'don', 'wouldn', 'there', 'just', "they're", 'hadn', 'both', 'own', 'being', 'd', 'doesn', 'themselves', "hadn't", 'no', 'that', 'our', 'didn', 'out', 'during', 'am', 'their', 'over', 'before', "you'd", "i'm", 'this', 'ain', 'mustn', 'from', "we're", 'after', 'about', "doesn't", "she'll"}
# ['get', 'free', 'copy', 'volume', '2', 'passiton', 'stories', 'ebook', 'filled', '25', 'new', 'inspirational', 'stories', 'around', 'world.', 'stories', 'give', 'lives', 'purpose', 'create', 'legacy', 'we’ve', 'done.', 'one', 'collection', 'true.', 'tell', 'overcoming,', 'meeting', 'unexpected', 'challenges,', 'innovation,', 'joys', 'life,', 'lessons', 'learned,', 'hope', 'restored.', 'often', 'happens,', 'story', 'well', 'told', 'reminds', 'us', 'important', 'stories.', 'trust', 'find', 'part', 'described', 'among', 'pages.', 'hope', 'enjoy', 'reading', 'stories', 'come', 'upon', 'something']

# %%
stemmer = PorterStemmer()
stemmed_words = [stemmer.stem(word) for word in filtered_tokens]
print(stemmed_words)
# Out:
# ['get', 'free', 'copi', 'volum', '2', 'passiton', 'stori', 'ebook', 'fill', '25', 'new', 'inspir', 'stori', 'around', 'world.', 'stori', 'give', 'live', 'purpos', 'creat', 'legaci', 'we’v', 'done.', 'one', 'collect', 'true.', 'tell', 'overcoming,', 'meet', 'unexpect', 'challenges,', 'innovation,', 'joy', 'life,', 'lesson', 'learned,', 'hope', 'restored.', 'often', 'happens,', 'stori', 'well', 'told', 'remind', 'us', 'import', 'stories.', 'trust', 'find', 'part', 'describ', 'among', 'pages.', 'hope', 'enjoy', 'read', 'stori', 'come', 'upon', 'someth']

# %%
lemmatizer = WordNetLemmatizer()
lemmatized_words = [lemmatizer.lemmatize(word) for word in filtered_tokens]
print(lemmatized_words)
# Out:
# ['get', 'free', 'copy', 'volume', '2', 'passiton', 'story', 'ebook', 'filled', '25', 'new', 'inspirational', 'story', 'around', 'world.', 'story', 'give', 'life', 'purpose', 'create', 'legacy', 'we’ve', 'done.', 'one', 'collection', 'true.', 'tell', 'overcoming,', 'meeting', 'unexpected', 'challenges,', 'innovation,', 'joy', 'life,', 'lesson', 'learned,', 'hope', 'restored.', 'often', 'happens,', 'story', 'well', 'told', 'reminds', 'u', 'important', 'stories.', 'trust', 'find', 'part', 'described', 'among', 'pages.', 'hope', 'enjoy', 'reading', 'story', 'come', 'upon', 'something']
